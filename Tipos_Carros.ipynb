# %% [markdown]
# <a href="https://colab.research.google.com/github/Epilef86/Python/blob/main/Tipos_Carros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# """
# Faça um programa que carregue uma lista com os modelos de cinco carros (exemplo
# de modelos: FUSCA, GOL, VECTRA etc). Carregue uma outra lista com o consumo
# desses carros, isto é, quantos quilômetros cada um desses carros faz com um
# litro de combustível. Calcule e mostre:
#
# a.	O modelo do carro mais econômico;
# b.	Quantos litros de combustível cada um dos carros cadastrados consome
# para percorrer uma distância de 1000 quilômetros e quanto isto custará,
# considerando um que a gasolina custe R$ 2,25 o litro.
#
# Abaixo segue uma tela de exemplo. O disposição das informações deve ser o mais
# próxima possível ao exemplo. Os dados são fictícios e podem mudar a cada
# execução do programa.
#
# Comparativo de Consumo de Combustível
#
# Veículo 1
# Nome: fusca
# Km por litro: 7
# Veículo 2
# Nome: gol
# Km por litro: 10
# Veículo 3
# Nome: uno
# Km por litro: 12.5
# Veículo 4
# Nome: vectra
# Km por litro: 9
# Veículo 5
# Nome: peugeout
# Km por litro: 14.5
#
# Relatório Final
#  1 - fusca           -    7.0 -  142.9 litros - R$ 321.43
#  2 - gol             -   10.0 -  100.0 litros - R$ 225.00
#  3 - uno             -   12.5 -   80.0 litros - R$ 180.00
#  4 - vectra          -    9.0 -  111.1 litros - R$ 250.00
#  5 - peugeout        -   14.5 -   69.0 litros - R$ 155.17
# O menor consumo é do peugeout.
# """

# %%
def main():
    print("Comparativo de Consumo de Combustível\n")

    lista = []

    for i in range(5):
        print("Veículo %i"%(i+1))
        nome = input("Nome: ")
        km = float(input("Km por Litro: "))
        lista.append([nome, km])

    print("\nRelatório Final")

    saidas = []

    for i in range(5):
        saidas.append(' %i - '%(i+1))
        
        #Nomes
        x = lista[i][0]
        Formata1(i, x, 16, saidas)

        saidas[i] +=' - '

        #Km por litro
        x = "%.1f"%lista[i][1]
        Formata2(i, x, 6, saidas)

        saidas[i] +=' - '

        #Litros a cada mil km
        x = "%.1f"%(1000/lista[i][1])
        Formata2(i, x, 6, saidas)

        saidas[i] += " litros - R$ "

        #R$ a cada mil km
        x = "%.2f"%(2250/lista[i][1])
        Formata2(i, x, 6, saidas)

        #Imprimindo Tudo
        print(saidas[i])


def Formata1(i, palavra, lmt, saida):
    if len(palavra) <= lmt:
        saida[i] += palavra + (lmt - len(palavra))*" "
        

def Formata2(i, palavra, lmt, saida):
    if len(palavra) <= lmt:
        saida[i] += (lmt - len(palavra))*" " + palavra

main()
# Out:
# Comparativo de Consumo de Combustível
#
# Veículo 1

# %% [markdown]
# modelo_carro = [ fusca, gol, uno, vectra, peugeout]
# consumo_carro = [7,10,12.5,9,14.5]
#
# a. modelo mais econômico
#
# b. 1000 km, quantos litros
#
#       litros(l)     consumo(km/l)                R$
#      	1	         7                      2.25
#
# 	x               1000                     y
#
#
# 1 Fusca:
#
# 	142.9
#
#
# lista = []
#
# for i=0 até 4:
# 	print(veiculo 1)
# 	nome = Nome: Fusca
# 	km = 7
# 	lista.append([Fusca, 7])
#
# lista = [[Fusca, 7],
#
# for i=1 até 4:
# 	print(veiculo 2)
# 	nome = Nome: gol
# 	km = 10
# 	lista.append([gol, 10])
#
# lista = [[Fusca, 7],[gol, 10])
#
# for i=2 até 4:
# 	print(veiculo 2)
# 	nome = Nome: uno
# 	km = 12.5
# 	lista.append([uno, 12.5])
#
# lista = [[Fusca, 7],[gol, 10],[uno, 12.5])
#
# for i=3 até 4:
# 	print(veiculo 2)
# 	nome = Nome: vectra
# 	km = 9
# 	lista.append([vectra, 9])
#
# lista = [[Fusca, 7],[gol, 10],[uno, 12.5],[vectra, 9])
#
# for i=4 até 4:
# 	print(veiculo 2)
# 	nome = Nome: peugeout
# 	km = 14.5
# 	lista.append([peugeout, 14.5])
#
# lista = [[Fusca, 7],[gol, 10],[uno, 12.5],[vectra, 9],[peugeout,14.5]]
#
#
#
# ----------------------------------------------------------------------------
# saidas = []
#
# for i=0 até 4:
# 	saidas.append(1-)
# 	saidas = ["1 - "]
#
# 	x= lista[0][0]
# 	formata1(0, "fusca", 16, "1 -") --> chama 1ª função
#
# -----------------------------------------------------------------------------
# 1ª função:
# 	def Formata1(i, palavra, lmt, saidas):
#
#     if len(palavra) <= lmt:
#     if 5 <= 16:
#
#         saidas[i] += palavra + (lmt - len(palavra))*" "
# 	saidas[0] += "1 -" + "fusca" + (16 - 5)*" "
# 	saidas[0] += "1 -" + "fusca" + (11)*" "
#
# -----------------------------------------------------------------------------
# #Nomes:
#
# 	saidas[0] = saidas[0] + " - "
# 	saidas[0] = " 1 - Fusca            - "
#
#
#
# 1 - Fusca            -
# 2 - gol
# 3 - uno
# 4 - vectra
# 5 - peugeout
#
# -------------------------------------------------------------------------------
# #Km por litro:
#
# 	x = (lista[0][1])
# 	x = (7)
# 	x = 7 km/l
#
# 	chama 2ª função:
#
# 		def Formata2(i, x, 6, saidas):
# 		def Formata2(0, "7", 6, [" 1 - Fusca            - "]):
#
#     if len(palavra) <= lmt:
#     if 1 <= 6:
#
#         saida[i] += (lmt - len(palavra))*" " + palavra
# 	saida[0] = " 1 - Fusca            - " + (6 - 1)*" " + "7"
# 	saida[0] = " 1 - Fusca            - " + 5*" " + "7"
#
# 1 - Fusca              - 7
#
# 	saidas[0] = "1 - Fusca            - 7" + " - "
#
# -------------------------------------------------------------------------------
# #Litros a cada mil km:
# 	x = (1000/lista[0][1])
# 	x = (1000/7)
# 	x = "142.9" km/l        -----> foi convertido em string por conta das aspas
#
#
# chama 2ª função:
# 	Formata2(i, x, 6, saidas)
# 	def Formata2(i, palavra, lmt, saida):
# 	def Formata2(0, "142.9", 6, ["1 - Fusca            - 7" + " - "]):
#
#     if len(palavra) <= lmt:
#     if 5 <= 6:
#         saida[0] = saida[0] + (lmt - len(palavra))*" " + palavra
# 	saida[0] = "1 - Fusca            - 7" + " - " + (6 - 5)*" " + "142.9"
#
# saida[0] = "1 - Fusca            - 7" + " - " + 1*" " + "142.9"
#
# saida[0] = "1 - Fusca            - 7" + " - " + 1*" " + "142.9" + " litros - R$ "
#
# escrita:
# 	1 - Fusca            - 7 - 142.9 litros - R$
#
# ------------------------------------------------------------------------------------
# #R$ a cada mil km:
# 	x = (2250/lista[0][1])
# 	x = (2250/7)
# 	x = 321.43           -----> foi convertido em string por conta das aspas
#
#
# chama 2ª função:
# 	Formata2(i, x, 6, saidas)
# 	def Formata2(i, palavra, lmt, saida):
# 	def Formata2(0, "321.43", 6, ["1 - Fusca            - 7" + " - " + 1*" " + "142.9" + " litros - R$ "]):
#
#     if len(palavra) <= lmt:
#     if 6 <= 6:
#         saida[0] = saida[0] + (lmt - len(palavra))*" " + palavra
# 	saida[0] = "1 - Fusca            - 7" + " - " + 1*" + "142.9" + " litros - R$ " + (6 - 6)*" " + "321.43"
# 	saida[0] = "1 - Fusca            - 7" + " - " + 1*" + "142.9" + " litros - R$ " + "321.43"
#
# ------------------------------------------------------------------------------------------------------------------
#
# Imprime na tela 1ª saída:
# 	1 - Fusca            - 7 - 142.9 litros - R$ 321.43
#
# ------------------------------------------------------------------------------------------------------------------
# Volta pro for
#
# for i=1 até 4:
# 	saidas.append(2 - )
# 	saidas = ["2 - "]
#
# 	x= lista[1][0]
# 	formata1(1, "gol", 16, "2 -") --> chama 1ª função e faz tudo novamente
